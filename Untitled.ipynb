# %%
C:\Users\Oldcar\Documents\github\Big_Leader_AI_Study\0629_prob.ipynb
# Out:
#   File "<ipython-input-1-a21f7e54f045>", line 1
#     C:\Users\Oldcar\Documents\github\Big_Leader_AI_Study\0629_prob.ipynb
#                                                                         ^
# SyntaxError: unexpected character after line continuation character
