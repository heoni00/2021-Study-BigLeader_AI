# %% [markdown]
# # 6월 29일 문제 풀이

# %%
# def score_board_make(txt):
#     f = open(txt, 'w')
#     print(f'{txt} 파일을 생성하였습니다!')
#     f.close()
    
# def write_score(txt):
#     f = open(txt, 'a')
#     score = input('점수를 입력하세요 : ')
#     f.write(f'{score},')
#     f.close()

# def print_score(txt):
#     f = open(txt, 'r')
#     data = f.readlines()[0]
#     scores = data.split(',')[:-1]
#     print('저장된 데이터입니다!')
#     print(scores)
#     # for score in scores:
#     #     temp = int(score)
#     #     print(f'{temp}')
        
#     tot = 0; n = len(scores)
#     for score in scores:
#         tot += int(score)
    
#     print(f'총합 : {tot}')
#     print(f'평균 : {tot/n}')
#     f.close()  

    
# def main():
#     i = 0
#     txt = 'score.txt'
#     score_board_make(txt)
#     while i < 10:
#         write_score(txt)
#         i += 1

#     print_score(txt)



i = 0
txt = 'score.txt'
f = open(txt, 'w')
print(f'{txt} 파일을 생성하였습니다!')
f.close()
    
f = open(txt, 'a')
while i < 10:
    score = input('점수를 입력하세요 : ')
    f.write(f'{score},')
    i += 1
f.close()
    
f = open(txt, 'r')
data = f.readlines()[0]
scores = data.split(',')[:-1]
print('저장된 데이터입니다!')
print(scores)
        
tot = 0; n = len(scores)
for score in scores:
    tot += int(score)
    
print(f'총합 : {tot}')
print(f'평균 : {tot/n}')
f.close()
